# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('waterOpStraat.tif', -1)
print(img)
# Out:
# [[-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#   -3.4028235e+38 -3.4028235e+38]
#  [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#   -3.4028235e+38 -3.4028235e+38]
#  [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#   -3.4028235e+38 -3.4028235e+38]
#  ...
#  [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#   -3.4028235e+38 -3.4028235e+38]
#  [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#   -3.4028235e+38 -3.4028235e+38]
#  [-3.4028235e+38 -3.4028235e+38 -3.4028235e+38 ... -3.4028235e+38
#   -3.4028235e+38 -3.4028235e+38]]

# %%
# show the image
plt.imshow(img,cmap='gray')
plt.axis('off')

# # save the image
# plt.savefig('gray.tif', transparent=True, dpi=300, bbox_inches="tight", pad_inches=0.0)
# Out:
# (-0.5, 1273.5, 1157.5, -0.5)

# %%
# show the image
plt.imshow(img,cmap='Reds_r')
plt.axis('off')

# # save the image
# plt.savefig('red.tif', transparent=True, dpi=300, bbox_inches="tight", pad_inches=0.0)
# Out:
# (-0.5, 1273.5, 1157.5, -0.5)

# %%
# show the image
plt.imshow(img)
plt.axis('off')

# # save the image
# plt.savefig('normal.tif', transparent=True, dpi=300, bbox_inches="tight", pad_inches=0.0)
# Out:
# (-0.5, 1273.5, 1157.5, -0.5)
